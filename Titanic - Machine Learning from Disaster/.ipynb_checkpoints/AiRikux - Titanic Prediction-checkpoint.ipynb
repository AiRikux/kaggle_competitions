# %% [markdown]
# # Titanic - Machine Learning from Disaster
#
# A kaggle prediction competition, view [here](https://www.kaggle.com/competitions/titanic/data?select=gender_submission.csv)
#
# 1. Libraries and Functions
# 2. Import Data
# 3. Analyse Data
# 4. Preprocessing
# 5. Train Data
# 6. Test Data
# 7. Export

# %% [markdown]
# # 1. Libraries and Functions
#
# - pandas: for making data to table form
# - seaborn: to make beautiful visualisations
# - matplotlib: to create graphs and plots

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# https://stackoverflow.com/questions/40372030/pandas-round-to-the-nearest-n
def roundasint(x, base=1):
    return int(base * round(float(x)/base))

# %% [markdown]
# # 2. Import Data
#
# Import data using pandas `read_csv`

# %%
test = pd.read_csv("data/test.csv")
train = pd.read_csv("data/train.csv")

# %% [markdown]
# # 3. Analyse Data

# %% [markdown]
# ## 1. See the first few rows of the data

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 2. Describe the data to see its numerical information

# %%
train.describe(include = "all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# ## 3. Create a correlation map using seaborn

# %%
sns.heatmap(train.corr(), cmap = "Blues", annot=True)
# Out:
# <Axes: >

# %%
pd.DataFrame(train.corr()['Survived']).sort_values(by='Survived', key=abs, ascending=False)[0:-1]
# Out:
#           Survived
# Survived  1.000000
# Pclass   -0.338481
# Fare      0.257307
# Parch     0.081629
# Age      -0.077221
# SibSp    -0.035322

# %% [markdown]
# ## Analysing Features
#
# Some features can be expanded as it raise some possible correlation
#
# 1. Does having any `SibSp` sibling/spouse aboard matter in survival?
#
# 2. Does having any `Parch` parents/children aboard matter in survival?
#
# 3. Is `Age` relevant to survival?
#
#     a. Does being older than 40 in `Age` relevant? Per human prime time is up to 40 years old.
#
#     b. Does being a child affect your survival chances?
#
#
# 4. Does having a better `Pclass` ticket class affect your survival?
#
# 5. Does fares affect the chances of survival?
#
# 6. Does having someone else in the same `Cabin` affect the correlation?

# %% [markdown]
# ### 1. Does having any `SibSp` sibling/spouse aboard matter in survival?

# %%
temp = train.loc[:,['SibSp','Survived']]

temp['nYes'] = [0]*len(temp)
temp['nNo'] = [0]*len(temp)

temp.loc[temp['Survived'] == 1, 'nYes'] = 1
temp.loc[temp['Survived'] == 0, 'nNo'] = 1

temp = temp.drop(columns = ['Survived']).groupby('SibSp').sum()

temp['Yes'] = 100 * (temp['nYes'] / (temp['nYes'] + temp['nNo']))
temp['No'] = 100 * (temp['nNo'] / (temp['nYes'] + temp['nNo']))

temp = temp.drop(columns = ['nYes', 'nNo'])

temp.plot(kind='bar', figsize=(20,5), title="Whether they Survived by number of Sibling/Spouse on board")
temp
# Out:
#              Yes          No
# SibSp
# 0      34.539474   65.460526
# 1      53.588517   46.411483
# 2      46.428571   53.571429
# 3      25.000000   75.000000
# 4      16.666667   83.333333
# 5       0.000000  100.000000
# 8       0.000000  100.000000

# %% [markdown]
# From the bar chart we can see the more siblings/spouses you have onboard, you will be more likely to not survive. From the graph we can see the cut off is at 4. From here we can group those that have `SibSp_big` "5 or more" and `SibSp_sml` "4 or less" to be able to further assess the feature's relevance.

# %%
temp = train.loc[:,['SibSp','Survived']]

temp['nYes'] = [0]*len(temp)
temp['nNo'] = [0]*len(temp)

temp.loc[temp['Survived'] == 1, 'nYes'] = 1
temp.loc[temp['Survived'] == 0, 'nNo'] = 1

temp['status'] = 'Small'
temp.loc[temp['SibSp'] >= 5, 'status'] = 'Big'

temp = temp.drop(columns = ['Survived', 'SibSp']).groupby('status').sum()

temp['Yes'] = 100 * (temp['nYes'] / (temp['nYes'] + temp['nNo']))
temp['No'] = 100 * (temp['nNo'] / (temp['nYes'] + temp['nNo']))

temp = temp.drop(columns = ['nYes', 'nNo'])

temp.plot(kind='bar', figsize=(20,5), title="Whether they Survived by whether they have 5 or more Sibling/Spouse on board")
temp
# Out:
#              Yes         No
# status
# Big      0.00000  100.00000
# Small   38.90785   61.09215

# %% [markdown]
# ### 2. Does having any `Parch` parents/children aboard matter in survival?

# %%
temp = train.loc[:,['Parch','Survived']]

temp['nYes'] = [0]*len(temp)
temp['nNo'] = [0]*len(temp)

temp.loc[temp['Survived'] == 1, 'nYes'] = 1
temp.loc[temp['Survived'] == 0, 'nNo'] = 1

temp = temp.drop(columns = ['Survived']).groupby('Parch').sum()

temp['Yes'] = 100 * (temp['nYes'] / (temp['nYes'] + temp['nNo']))
temp['No'] = 100 * (temp['nNo'] / (temp['nYes'] + temp['nNo']))

temp = temp.drop(columns = ['nYes', 'nNo'])

temp.plot(kind='bar', figsize=(20,5), title="Whether they Survived by number of Parents/Children on board")
temp
# Out:
#              Yes          No
# Parch
# 0      34.365782   65.634218
# 1      55.084746   44.915254
# 2      50.000000   50.000000
# 3      60.000000   40.000000
# 4       0.000000  100.000000
# 5      20.000000   80.000000
# 6       0.000000  100.000000

# %% [markdown]
# Though, if the amount of parents/children you have is 4 and above it will greatly decrease your chance to survive, the numbers are misleading as one could be children, who are dependant, or parents who might be able to increase the chance of survival.
#
# Let's dwelve deeper by catgorising them to yes, they have parents or sibling, and no, they do not have parents or sibling aboard.

# %%
temp = train.loc[:,['Parch','Survived']]

temp['nYes'] = [0]*len(temp)
temp['nNo'] = [0]*len(temp)

temp.loc[temp['Survived'] == 1, 'nYes'] = 1
temp.loc[temp['Survived'] == 0, 'nNo'] = 1

temp['status'] = 'PC'
temp.loc[temp['Parch'] == 0, 'status'] = 'NoPC'

temp = temp.drop(columns = ['Survived', 'Parch']).groupby('status').sum()

temp['Yes'] = 100 * (temp['nYes'] / (temp['nYes'] + temp['nNo']))
temp['No'] = 100 * (temp['nNo'] / (temp['nYes'] + temp['nNo']))

temp = temp.drop(columns = ['nYes', 'nNo'])

temp.plot(kind='bar', figsize=(20,5), title="Whether they Survived when they have Parents/Children on board")
temp
# Out:
#               Yes         No
# status
# NoPC    34.365782  65.634218
# PC      51.173709  48.826291

# %% [markdown]
# From the division above, whether you have parents/children on board, there seems to have no pattern.
#
# We'll explore whether the division of having 4 or more parents/children aboard affect the chance of survival.

# %%
temp = train.loc[:,['Parch','Survived']]

temp['nYes'] = [0]*len(temp)
temp['nNo'] = [0]*len(temp)

temp.loc[temp['Survived'] == 1, 'nYes'] = 1
temp.loc[temp['Survived'] == 0, 'nNo'] = 1

temp['status'] = 'Small'
temp.loc[temp['Parch'] >= 4, 'status'] = 'Big'

temp = temp.drop(columns = ['Survived', 'Parch']).groupby('status').sum()

temp['Yes'] = 100 * (temp['nYes'] / (temp['nYes'] + temp['nNo']))
temp['No'] = 100 * (temp['nNo'] / (temp['nYes'] + temp['nNo']))

temp = temp.drop(columns = ['nYes', 'nNo'])

temp.plot(kind='bar', figsize=(20,5), title="Whether they Survived when they have 4 or more Parents/Children on board")
temp
# Out:
#               Yes         No
# status
# Big     10.000000  90.000000
# Small   38.706016  61.293984

# %% [markdown]
# Having 3 or less parents/children on board does not seem to heavily affect the survival. However, there is an obvious failure rate when having 4 or more parents/children on board, Thus we will add the feature `Parch_big`

# %% [markdown]
# ### 3. Is `Age` relevant to survival?
#
# There seem to be no obvious pattern in age. The people aged 60 or older only have limited number of people so we cannot consider it as a "for sure" chance. Thus, we will dwelve deeper.
#
# a. Does being older than 40 in `Age` relevant? Per human prime time is up to 40 years old.
#
# b. Does being a child affect your survival chances?

# %%
temp = train.loc[:,['Age','Survived']]

# remove those with Null in Age
temp = temp[~temp['Age'].isnull()]
# round as integer
temp['Age'] = temp['Age'].apply(lambda x: roundasint(x, 1))
# create default value as 0 for number of grouping later
temp['nYes'] = 0
temp['nNo'] = 0
# if survived it will add to the count by one
temp.loc[train['Survived'] == 1, 'nYes'] = 1
temp.loc[train['Survived'] == 0, 'nNo'] = 1
# group and sum the values
temp = temp.drop(columns = ['Survived']).groupby('Age').sum()
# set as percentage for visualisation
temp['Yes'] = 100 * (temp['nYes'] / (temp['nYes'] + temp['nNo']))
temp['No'] = 100 * (temp['nNo'] / (temp['nYes'] + temp['nNo']))
# drop irrelevant columns
temp = temp.drop(columns = ['nYes', 'nNo'])
# visualise
temp.plot(kind='bar', figsize=(20,5), title="Whether they Survived by Age")
# Out:
# <Axes: title={'center': 'Whether they Survived by Age'}, xlabel='Age'>

# %% [markdown]
# From the graph above, we can't see any pattern of survival from wheter a specific age range would survive the titanic.
#
# Analysing based on the age itself might not give the best visualisation result. Thus, we will group them by tens in age to see if a certain age group, based on natural rounding, is more likely to survive.

# %%
temp = train.loc[:,['Age','Survived']]

# remove those with Null in Age
temp = temp[~temp['Age'].isnull()]
# round as integer by 10
temp['Age'] = temp['Age'].apply(lambda x: roundasint(x, 10))
# create default value as 0 for number of grouping later
temp['nYes'] = 0
temp['nNo'] = 0
# if survived it will add to the count by one
temp.loc[train['Survived'] == 1, 'nYes'] = 1
temp.loc[train['Survived'] == 0, 'nNo'] = 1
# group and sum the values
temp = temp.drop(columns = ['Survived']).groupby('Age').sum()
# set as percentage for visualisation
temp['Yes'] = 100 * (temp['nYes'] / (temp['nYes'] + temp['nNo']))
temp['No'] = 100 * (temp['nNo'] / (temp['nYes'] + temp['nNo']))
# drop irrelevant columns
temp = temp.drop(columns = ['nYes', 'nNo'])
# visualise
temp.plot(kind='bar', figsize=(20,5), title="Whether they Survived by Age (Grouped by 10)")
# Out:
# <Axes: title={'center': 'Whether they Survived by Age (Grouped by 10)'}, xlabel='Age'>

# %% [markdown]
# There still no apparent pattern seen as we group the age by tens. The apparent 100% on 70 and 80 is due to it being only one sample for the group which we may consider an outlier.
#
# From this graph we can also see that being children at 0 or 10 does not mean that your rate of survival is apparent.

# %%
temp = train.loc[:,['Age','Survived']]

# remove those with Null in Age
temp = temp[~temp['Age'].isnull()]
# set age limit
age_lim = 40
# set default values
temp['Age_grp'] = f"{age_lim} or less"
temp['nYes'] = 0
temp['nNo'] = 0
# change default values to group and count for visualisation
temp.loc[train['Age'] > age_lim, "Age_grp"] = f"{age_lim} above"
temp.loc[train['Survived'] == 1, 'nYes'] = 1
temp.loc[train['Survived'] == 0, 'nNo'] = 1
# group by and sum to count
temp = temp.drop(columns = ['Survived']).groupby('Age_grp').sum()
# convert to percentage for ease of view in visualisation
temp['Yes'] = 100 * (temp['nYes'] / (temp['nYes'] + temp['nNo']))
temp['No'] = 100 * (temp['nNo'] / (temp['nYes'] + temp['nNo']))
# drop irrelevant columns
temp = temp.drop(columns = ['nYes', 'nNo', 'Age'])
# visualise
temp.plot(kind='bar', figsize=(20,5), title="Whether they Survived by Age Group", xlabel="Age Group")

temp
# Out:
#                   Yes         No
# Age_grp
# 40 above    36.666667  63.333333
# 40 or less  41.666667  58.333333

# %% [markdown]
# Above distribution is based whether you are in a prime age or beyond the prime age. Again, here both groups have similar results which means there is no apparent reason for being in a prime age or not would affect you to survive.
#
# Based on this analysis there is no apparent reason for age to be a relevant feature to determine if a person would survive.

# %% [markdown]
# ### 4. Does having a better `Pclass` ticket class affect your survival?

# %%
temp = train.loc[:,['Pclass','Survived']]

temp['nYes'] = [0]*len(temp)
temp['nNo'] = [0]*len(temp)

temp.loc[temp['Survived'] == 1, 'nYes'] = 1
temp.loc[temp['Survived'] == 0, 'nNo'] = 1

temp = temp.drop(columns = ['Survived']).groupby('Pclass').sum()

temp['Yes'] = 100 * (temp['nYes'] / (temp['nYes'] + temp['nNo']))
temp['No'] = 100 * (temp['nNo'] / (temp['nYes'] + temp['nNo']))

temp = temp.drop(columns = ['nYes', 'nNo'])

temp.plot(kind='bar', figsize=(20,5), title="Whether they Survived based on their ticket class")
temp
# Out:
#               Yes         No
# Pclass
# 1       62.962963  37.037037
# 2       47.282609  52.717391
# 3       24.236253  75.763747

# %% [markdown]
# Based on the bar graph, those in cabin 3 have almost no chance of survival. Let's group them to those in class 3 `Pclass_3` and not `Pclass_not3`

# %%
temp = train.loc[:,['Pclass','Survived']]

temp['nYes'] = [0]*len(temp)
temp['nNo'] = [0]*len(temp)

temp.loc[temp['Survived'] == 1, 'nYes'] = 1
temp.loc[temp['Survived'] == 0, 'nNo'] = 1

temp['status'] = 'Pclass_3'
temp.loc[temp['Pclass'] != 3, 'status'] = 'Pclass_not3'

temp = temp.drop(columns = ['Survived', 'Pclass']).groupby('status').sum()

temp['Yes'] = 100 * (temp['nYes'] / (temp['nYes'] + temp['nNo']))
temp['No'] = 100 * (temp['nNo'] / (temp['nYes'] + temp['nNo']))

temp = temp.drop(columns = ['nYes', 'nNo'])

temp.plot(kind='bar', figsize=(20,5), title="Whether they Survived based on their ticket class")
temp
# Out:
#                    Yes         No
# status
# Pclass_3     24.236253  75.763747
# Pclass_not3  55.750000  44.250000

# %% [markdown]
# Here it is obvious that being in Class 3 greatly decrease your chance of survival.

# %% [markdown]
# ### 5. Does fares affect the chances of survival?
#
#     From what we know fares vary from passenger even if they have the same `Pclass`. Thus we need to see the distribution of fares to the survival rate. We'll group them based on the median 14.4542.

# %%
temp = train.loc[:,['Fare','Survived']]

temp['nYes'] = [0]*len(temp)
temp['nNo'] = [0]*len(temp)

temp.loc[temp['Survived'] == 1, 'nYes'] = 1
temp.loc[temp['Survived'] == 0, 'nNo'] = 1

temp['status'] = 'below_med'
temp.loc[temp['Fare'] >= 14.4542, 'status'] = 'above_med'

temp = temp.drop(columns = ['Survived', 'Fare']).groupby('status').sum()

temp['Yes'] = 100 * (temp['nYes'] / (temp['nYes'] + temp['nNo']))
temp['No'] = 100 * (temp['nNo'] / (temp['nYes'] + temp['nNo']))

temp = temp.drop(columns = ['nYes', 'nNo'])

temp.plot(kind='bar', figsize=(20,5), title="Whether they Survived based on whether their fare is below the median")
temp
# Out:
#                  Yes         No
# status
# above_med  51.219512  48.780488
# below_med  25.227273  74.772727

# %% [markdown]
# We can see that those that pay for the fare lower than the median, they will not likely to survive. We can create a feature for those that pay a fare lower than the median as `Fare_bmed`.
#
# To see the larger distribution we group the fares by 5.

# %%
temp = train.loc[:,['Fare','Survived']]

# remove those with Null in Age
temp = temp[~temp['Fare'].isnull()]
# round as integer by 10
temp['Fare'] = temp['Fare'].apply(lambda x: roundasint(x, 5))
# create default value as 0 for number of grouping later
temp['nYes'] = 0
temp['nNo'] = 0
# if survived it will add to the count by one
temp.loc[train['Survived'] == 1, 'nYes'] = 1
temp.loc[train['Survived'] == 0, 'nNo'] = 1
# group and sum the values
temp = temp.drop(columns = ['Survived']).groupby('Fare').sum()
# set as percentage for visualisation
temp['Yes'] = 100 * (temp['nYes'] / (temp['nYes'] + temp['nNo']))
temp['No'] = 100 * (temp['nNo'] / (temp['nYes'] + temp['nNo']))
# drop irrelevant columns
temp = temp.drop(columns = ['nYes', 'nNo'])
# visualise
temp.plot(kind='bar', figsize=(20,5), title="Whether they Survived by Fare (Grouped by 5)")
# Out:
# <Axes: title={'center': 'Whether they Survived by Age (Grouped by 5)'}, xlabel='Fare'>

# %%
temp = train.loc[:,['Fare','Survived']]

temp['nYes'] = [0]*len(temp)
temp['nNo'] = [0]*len(temp)

temp.loc[temp['Survived'] == 1, 'nYes'] = 1
temp.loc[temp['Survived'] == 0, 'nNo'] = 1

temp['status'] = 'below_90'
temp.loc[temp['Fare'] >= 90, 'status'] = 'above_90'

temp = temp.drop(columns = ['Survived', 'Fare']).groupby('status').sum()

temp['Yes'] = 100 * (temp['nYes'] / (temp['nYes'] + temp['nNo']))
temp['No'] = 100 * (temp['nNo'] / (temp['nYes'] + temp['nNo']))

temp = temp.drop(columns = ['nYes', 'nNo'])

temp.plot(kind='bar', figsize=(20,5), title="Whether they Survived based on whether their fare is below $90")
temp
# Out:
#                 Yes         No
# status
# above_90  75.409836  24.590164
# below_90  35.662651  64.337349

# %% [markdown]
# # 4. Preprocessing

# %% [markdown]
# ## Remove Features
# Here we see some data that might not relate to whether they survive, one is `Name` as it is just strings that does not hold value. So we can remove that ahead.

# %%
train = train.drop(columns=['Name'])

# %% [markdown]
# ## Remove Outliers
#
# We focus on those columns that are not categorical, as they may be more likely to have outliers. We start from the lowest correlation where we see the relationship of the features with its result.

# %% [markdown]
# ### Outlier in `SibSp`

# %%
sns.barplot(x = train['Survived'], y = train['SibSp'])
# Out:
# <Axes: xlabel='Survived', ylabel='SibSp'>

# %% [markdown]
# ### Outlier in `Age`

# %%
sns.regplot(x = train['Survived'], y = train['Age'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
train.boxplot(['Fare'])
# Out:
# <Axes: >

# %% [markdown]
# ## Handling Nulls
#
# Notice in the analysis above some counts are incomplete due to null values, we will look further into those.

# %% [markdown]
# ### Nulls in `Age`
#
# From the analysis there are only 714 count of age entry. We cannot leave them in nor fill them with 0 as age below 1 is included.

# %%
train.loc[train['Age'].isna(),'Age'] = train['Age'].mean()

# %% [markdown]
# ### Nulls in `embarked`
#
# There are only 2 people with null in embarked and they all survived. Which meaned they did not depart on the boat. We will remove them from the sample

# %%
train = train.loc[~train['embarked'].isna()]

# %% [markdown]
# ## Creating Features
#
# We will create new features based on our previous analysis.

# %% [markdown]
# ### From `SibSp`
#
# We will create:
# * `SibSp_big`: If they have `SibSp` 5 or more then 1, else 0
# * `Parch_big`: If they have `Parch` 4 or more then 1, else 0
# * `Pclass_3` : If they are in Class 3 then 1, else 0
# * `Fare_bmed` : If they pay for a fare less than the median then 1, else 0

# %%
# Creation of SibSp_big
train['SibSp_big'] = [0]*len(train)
train.loc[train['SibSp'] >= 5, 'SibSp_big'] = 1

# Creation of Parch_big
train['Parch_big'] = [0]*len(train)
train.loc[train['Parch'] >= 4, 'Parch_big'] = 1

# Creation of Pclass_3
train['Pclass_3'] = [0]*len(train)
train.loc[train['Pclass'] == 3, 'Pclass_3'] = 1


# Creation of Fare_bmed
train['Fare_bmed'] = [0]*len(train)
train.loc[train['Fare'] < 14.4542, 'Fare_bmed'] = 1

# %% [markdown]
# ### Whether there are other people in the cabin from `ticket`

# %% [markdown]
# ## 5. Train Data

# %%
sns.heatmap(train1.corr(), cmap = "Blues", annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(train2.corr(), cmap = "Blues", annot=True)
# Out:
# <AxesSubplot:>

# %%
train[train['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
train[train['Ticket'] == "113572"]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  SibSp_big  SibSp_sml
# 0      0         A/5 21171   7.2500   NaN        S          0          1
# 1      0          PC 17599  71.2833   C85        C          0          1
# 2      0  STON/O2. 3101282   7.9250   NaN        S          0          1
# ...

# %%
sns.heatmap(train.corr(), cmap = "Blues", annot=True)
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(train.corr()['Survived']).sort_values(by='Survived', key=abs)[0:-1]
# Out:
#              Survived
# PassengerId -0.005007
# SibSp       -0.035322
# Age         -0.077221
# Parch        0.081629
# SibSp_sml    0.092220
# SibSp_big   -0.092220
# Fare         0.257307
# Pclass      -0.338481
